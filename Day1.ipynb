# %%
stri = "Dear professor.........."
stri.replace("Dear","Hello")
# Out:
# 'Hello professor..........'

# %%
stri.replace("e","C",2)
# Out:
# 'DCar profCssor..........'

# %%
stri.replace("D", "HII", 1)
# Out:
# 'HIIear professor..........'

# %%
string = "I'am Samruddhi #14"
type(string)
# Out:
# str

# %%
"How are you".endswith("g")
# Out:
# False

# %%
a = "Welcome"
print(((a.upper()).lower()).capitalize())
print(a.upper().lower().capitalize())
# Out:
# Welcome
# Welcome

# %%
a = 15.66
b = int(a)
b
# Out:
# 15

# %% [markdown]
# Data structures in python
#
# organizing the data,collection, storing,managing,structuring
#
# 1.list 2.Tuple 3.Dict 4.Set

# %% [markdown]
# **#LIST**
#
# 1. python data structure
# 2. changeable -> CURD(create,read,update,delete)
# 3. Heterogeneuos value -
# 4. Allows duplicate values

# %%
list = ["cat","dog","goat","pig"]
type(list)
# Out:
# list

# %%
list = ("cat","dog","goat","pig")
type(list)
# Out:
# tuple

# %%
list[3]
# Out:
# 'pig'

# %%
list[-3]
# Out:
# 'dog'

# %%
list[1:3]
# Out:
# ('dog', 'goat')

# %%
str = "Hello World"
str[0:9:2]
# Out:
# 'HloWr'

# %% [markdown]
# U-> update list

# %%
lis = ["a","b","c","d","e"]
lis[2] = "Cow"
print(lis)
# Out:
# ['a', 'b', 'Cow', 'd', 'e']

# %%
lis.append("g")
lis
# Out:
# ['a', 'b', 'Cow', 'd', 'e', 'GG', 'g', 'g', 'g', 'g']

# %%
lis.insert(1,"Pencil")
lis
# Out:
# ['a', 'Pencil', 'b', 'Cow', 'd', 'e', 'GG', 'g', 'g', 'g', 'g']

# %%
elec = ["Fan", "Bulb", "AC"]
games = ["Cricket", "Football", "Hockey"]


elec.extend(games)
elec
# Out:
# ['Fan', 'Bulb', 'AC', 'Cricket', 'Football', 'Hockey']

# %% [markdown]
# # To perform deletion
#
# remove(give me name of the element)
# pop(give me index)
# del

# %%
elec.remove("Fan")

# %%
elec
# Out:
# ['Bulb', 'AC', 'Cricket', 'Football', 'Hockey']

# %%
elec.pop(-1)
# Out:
# 'Hockey'

# %%
elec
# Out:
# ['Bulb', 'AC', 'Cricket', 'Football']

# %%
listi = [[1,2,3],[4,5,6]]
listi[0]
# Out:
# [1, 2, 3]

# %%
listi[1][0]
# Out:
# 4

# %%
listi[1].remove(4)
listi
# Out:
# [[1, 2, 3], [5, 6]]

# %%
del listi[0]
listi
# Out:
# [[5, 6]]

# %%
grades = [34,57,98,77,89]

# %%
len(grades)
# Out:
# 5

# %%
max(grades)
# Out:
# 98

# %%
min(grades)
# Out:
# 34

# %%
alph = ["Hello","World","cat"]

max(alph)
# Out:
# 'cat'

# %%
min(alph)
# Out:
# 'Hello'

# %%
grades
# Out:
# [34, 57, 98, 77, 89]

# %%
grades.sort()

# %%
grades
# Out:
# [34, 57, 77, 89, 98]

# %%
grades.sort(reverse=True)
grades
# Out:
# [98, 89, 77, 57, 34]

# %%
grades.reverse()
grades
# Out:
# [34, 57, 77, 89, 98]
