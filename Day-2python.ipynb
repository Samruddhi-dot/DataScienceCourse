# %% [markdown]
# Tuple
#
# 1. Data structure
# 2. Immutable
# 3. ()
# 4. it allows the duplicacy

# %%
tup1 = ("Apples","Bananas","Mangoes","Cherries")
print(tup1)
# Out:
# ('Apples', 'Bananas', 'Mangoes', 'Cherries')

# %%
type(tup1)
# Out:
# tuple

# %%
tup1[2]
# Out:
# 'Mangoes'

# %%
lis = list(tup1)

# %%
lis
# Out:
# ['Apples', 'Bananas', 'Mangoes', 'Cherries']

# %%
tup1[0:3]
# Out:
# ('Apples', 'Bananas', 'Mangoes')

# %% [markdown]
# Tuple --> List ---> Perform the operations -->Tuple

# %%
tup1 = ("Apples","Bananas","Mangoes","Cherries")

# %%
tuples = ('pear')

# %%
tup2 = (1,2,3,4,4,5,9)

# %%
tup2.count(4)
# Out:
# 2

# %%
#find index

tup2.index(2)
# Out:
# 1

# %% [markdown]
# dictionary
#
# 1. Python data structure
# 2. {}
# 3. key:value pair
# 4. mutable --> changable

# %%
di = {"table":"A wooden plank or a sheet"}

# %%
type(di)
# Out:
# dict

# %%
di = {"table":"A wooden plank or a sheet","table":"it is a toy"}

# %%
di   #it will take the last value because last occurence is taken
# Out:
# {'table': 'it is a toy'}

# %%
dictio = {"book":"knowledge","laptop":"elec","pen":"an instrument"}

# %%
#CURD

# %%
dictio["book"]   #->list
# Out:
# 'knowledge'

# %%
dictio.get("book")#dictionary
# Out:
# 'knowledge'

# %%
dictio["book"] = "Hello world"

# %%
dictio
# Out:
# {'book': 'Hello world', 'laptop': 'elec', 'pen': 'an instrument'}

# %%
#update()

dictio.update({"book":"pages"})  #dict concept

# %%
dictio
# Out:
# {'book': 'pages', 'laptop': 'elec', 'pen': 'an instrument'}

# %%
#remove a dict

dictio.pop("laptop")
# Out:
# 'elec'

# %%
dictio
# Out:
# {'book': 'pages', 'pen': 'an instrument'}

# %%
#popitem it will remove the last element (by default)

# %%
dictio.popitem()
# Out:
# ('pen', 'an instrument')

# %%
dictio.clear()
dictio
# Out:
# {}

# %%
loop = {'A':'a','B':'b','C':'c'}

# %%
loop.values()
# Out:
# dict_values(['a', 'b', 'c'])

# %%
loop.keys()
# Out:
# dict_keys(['A', 'B', 'C'])

# %%
dics = {'python':{'data':12}}   #value is inside the datatype so it doesnt matter what values it is

# %%
dics
# Out:
# {'python': {'data': 12}}
