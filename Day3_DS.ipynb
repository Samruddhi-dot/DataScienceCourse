# %% [markdown]
# Condtional Statements  -->if,elif,else

# %%
a == b
a != b
a < b
a > b
a >= b
a <= b

# %%
#Italy vs England

if England wins --> I'am getting 5000 extra
if Italy wins -> I'am getting 3000 extra

# %%
winner = input("Who is the winner: ")


if winner == "England":
    print("I'am getting 5000 extra")
else:
    print("I'am getting 3000 extra")
# Out:
# Who is the winner: italy
# I'am getting 3000 extra

# %%
price = int(input("Enter the price: "))

if price<100:
  print("Buy some snacks")
elif price==100:
  print("Buy clothes")
else:
  print("Buy a car")
# Out:
# Enter the price: 99
# Buy some snacks

# %%
stri = "Money"

# %%
stri == False
# Out:
# False

# %%
try:
  if stri:
    print("Money")
except:
  print("No Money")
# Out:
# Money

# %%
listi = ["Mr bean","Tom & jerry","Harry potter"]

# %%
if "doraemon" in listi:
  print("Yes")
else:
  print("No")
# Out:
# No

# %%
imp = input("Enter name : ")

if imp.isnumeric():
  print("sorry")
elif imp.isalpha():
  print("you are nice")
else:
  print("you are funny")
# Out:
# Enter name : 1111111
# sorry
