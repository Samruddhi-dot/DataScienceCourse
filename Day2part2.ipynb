# %% [markdown]
# sets
#
# 1. python datastructure
# 2. {}
# 3. unordered
# 4. unchangable -> inbuilt
# 5. it does not support duplicacy

# %%
seti = {11,3,7,1,8}

# %%
type(seti)
# Out:
# set

# %%
seti
# Out:
# {1, 3, 7, 8, 11}

# %%
setii = {1,2,3,4,5,1,2,3,4,1,1}

# %%
setii
# Out:
# {1, 2, 3, 4, 5}

# %%
#Access the elements in the set


seti = {"apples","mangoes","cherries"}

# %%
seti
# Out:
# {'apples', 'cherries', 'mangoes'}

# %%
seti[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-dbb4114f81fd> in <cell line: 1>()
# ----> 1 seti[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# To access the element in the set
#
# Convert the set to list

# %%
listi = list(seti)

# %%
listi[0] = "Bananas"

# %%
listi
# Out:
# ['Bananas', 'apples', 'mangoes']

# %%
listi[1]
# Out:
# 'apples'

# %%
seti = set(listi)

# %%
seti
# Out:
# {'Bananas', 'apples', 'mangoes'}

# %%
#CRUD

set_a = {"apples","mangoes","cherries"}
set_b = {"oranges"}

#Adding up two sets

set_a.update(set_b)

# %%
set_a
# Out:
# {'apples', 'cherries', 'mangoes', 'oranges'}

# %%
set_a.add("grapes")

# %%
set_a
# Out:
# {'apples', 'cherries', 'grapes', 'mangoes', 'oranges'}

# %%
#Sets  delete
#remove()

# %%
set_a.remove("cherries")    #select the element to remove

# %%
set_a.discard("grapes")

# %%
set_a
# Out:
# {'apples', 'mangoes', 'oranges'}

# %%
#clear()

set_a.clear()

# %%
set_a
# Out:
# set()

# %%
set_a = {"apples","bananas","cherries"}
set_b = {"google","microsoft","apples"}

# %%
set_c = set_a.union(set_b)

# %%
set_c
# Out:
# {'apples', 'bananas', 'cherries', 'google', 'microsoft'}

# %%
set_d = set_a.intersection(set_b)

# %%
set_d
# Out:
# {'apples'}

# %%
set_e = set_a.difference(set_b)

# %%
set_e
# Out:
# {'bananas', 'cherries'}
